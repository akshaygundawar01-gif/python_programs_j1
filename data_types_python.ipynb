# %% [markdown]
# # data type in python
# 1.different types of values assigned to variaables
# 2.basically 3 data types in python
# 3.int(integer) -numerical values like 1,2,3,4....n
# 4.str(string)-charecters examples "abcd",ghjk

# %%
name="vikas"
age=25
salary=100023.25
data="123"
print(name)
print(salary)
print(data)
print(type(name))
print(type(age))
print(type(salary))
print(type(data))
# Out:
# vikas
# 100023.25
# 123
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
# concatenations
a=100
b=200
print(a+b)
# Out:
# 300

# %%
n1="python"
n2='programming"
print(n1+n2)
# Out:
#   Cell In[3], line 2
#     n2='programming"
#        ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
a=100
b="300"
print(a+int(b))
# Out:
# 400
